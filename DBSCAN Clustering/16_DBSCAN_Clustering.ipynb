# %% [markdown]
# # **DBSCAN Clustering**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import dataset
dataset = pd.read_csv('Mall_Customers.csv')
dataset.head()

# %%
dataset.shape
dataset.info()

# %%
# Selecting features (Annual Income and Spending Score)
X = dataset.iloc[:, [3, 4]].values

# %%
a = dataset.iloc[:, 3]
b = dataset.iloc[:, 4]

# Plot original data
plt.scatter(a, b)
plt.show()

# %% [markdown]
# # **Modelling**

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps=5,min_samples=5)

# %%
y_dbs=dbs.fit_predict(X)

# %%
y_dbs

# %%
np.unique(y_dbs)

# %% [markdown]
# # **Visualising the clusters**

# %%
# Visualising the clusters
plt.scatter(X[y_dbs == -1, 0], X[y_dbs == -1, 1], s = 100, c = 'red', label = 'Cluster -1')
plt.scatter(X[y_dbs == 0, 0], X[y_dbs == 0, 1], s = 100, c = 'magenta', label = 'Cluster 0')
plt.scatter(X[y_dbs == 1, 0], X[y_dbs == 1, 1], s = 100, c = 'blue', label = 'Cluster 1')
plt.scatter(X[y_dbs == 2, 0], X[y_dbs == 2, 1], s = 100, c = 'green', label = 'Cluster 2')
plt.scatter(X[y_dbs == 3, 0], X[y_dbs == 3, 1], s = 100, c = 'cyan', label = 'Cluster 3')
plt.scatter(X[y_dbs == 4, 0], X[y_dbs == 4, 1], s = 100, c = 'yellow', label = 'Cluster 4')

plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
